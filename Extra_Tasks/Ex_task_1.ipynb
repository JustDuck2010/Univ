# %% [markdown]
# <a href="https://colab.research.google.com/github/JustDuck2010/University/blob/main/Extra_Tasks/Ex_task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import re

print('Угадайте загаданное число (от 0 до 100)')
gen = int(random.randint(0, 100))
t, sk = 0, 0
min = 100
f = 1
while f == 1:
    if sk == 0:
        num  = input('Введите число: ').lower()
    sk = 0
    if num != 'выход':
         num = re.sub("[^0-9]", "", num)
         t += 1
    if int(num) > gen:
        print('Слишком большое
        ')
    elif int(num) < gen:
        print('Слишком маленькое')
    else:
        print(f'\nВы угадали число! Количество попыток: {t} \n\n✕Если хотите закончить игру, напишите "выход" \n✓Если хотите продолжить игру, введите новое предположение\n' )
        if t < min:
            min = t
        a = input()
        if a.lower() == 'выход':
            print(f'Меньшее количество попыток: {min}')
            f = 0
        else:
            gen = int(random.randint(0, 100))
            num = re.sub("[^0-9]", "", a) # искать все символы в переменной "a" кроме чисел от 0 до 9, все что будет найдено - заменить на пустую строку
            sk = 1
            t = 0
# Out:
# Угадайте загаданное число (от 0 до 100)
# Введите число: 50
# Слишком маленькое
# Введите число: 75
# Слишком большое
# Введите число: 63
# Слишком большое
# Введите число: 57
# Слишком маленькое
# Введите число: 60
# Слишком маленькое
# Введите число: 62
# Слишком большое
# Введите число: 61
#
# Вы угадали число! Количество попыток: 7
#
# ✕Если хотите закончить игру, напишите "выход"
# ✓Если хотите продолжить игру, введите новое предположение
#
# 50
# Слишком большое
# Введите число: 25
# Слишком большое
# Введите число: 15
# Слишком маленькое
# Введите число: 23
# Слишком большое
# Введите число: 22
# Слишком большое
# Введите число: 21
# Слишком большое
# Введите число: 20
# Слишком большое
# Введите число: 18
# Слишком большое
# Введите число: 17
#
# Вы угадали число! Количество попыток: 9
#
# ✕Если хотите закончить игру, напишите "выход"
# ✓Если хотите продолжить игру, введите новое предположение
#
# 50
# Слишком большое
# Введите число: 25
# Слишком маленькое
# ...
